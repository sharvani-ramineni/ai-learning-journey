# %% [markdown]
# <a href="https://colab.research.google.com/github/sharvani-ramineni/ai-learning-journey/blob/main/week-01-llm-fundamentals/day-01-tokenization/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Everything is going to be great - Keep learning and keep building")
# Out:
# Everything is going to be great - Keep learning and keep building
